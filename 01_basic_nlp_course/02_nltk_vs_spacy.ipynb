# %% [markdown]
# # Basic NLP Course
#
# ## NLTK vs spaCy
#
# This is the second class of the Basic NLP Course, where we will explore two popular Python libraries for Natural Language Processing: NLTK and spaCy. These packages provide powerful tools for text processing, tokenization, parsing, and more.
#
# spaCy adopts an object-oriented approach, making it ideal for those who prioritize the end result and need efficient pipelines for NLP tasks. On the other hand, NLTK relies on string processing, offering access to a wide range of algorithms and greater flexibility for customizations, making it suitable for those who want to experiment and fine-tune their workflows.

# %%
import nltk
import spacy
from nltk.tokenize import sent_tokenize, word_tokenize

# Load the small English NLP model
nlp = spacy.load("en_core_web_sm")

# load packages for nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
work_order = "Work Order: Maintenance required for HVAC system in Building A. Priority: High. Assigned to: John Doe."
print(work_order)

# Process the text with spaCy
doc = nlp(work_order)
# Out:
# Work Order: Maintenance required for HVAC system in Building A. Priority: High. Assigned to: John Doe.

# %%
# sentence tokenization
for sentence in doc.sents:
    print(sentence)
# Out:
# Work Order: Maintenance required for HVAC system in Building A. Priority: High.
# Assigned to: John Doe.

# %%
# word tokenization
for sentence in doc.sents:
    for word in sentence:
        print(word)
# Out:
# Work
# Order
# :
# Maintenance
# required
# for
# HVAC
# system
# in
# Building
# A.
# Priority
# :
# High
# .
# Assigned
# to
# :
# John
# Doe
# .

# %%
# analysing types of objects
print(type(doc))
print(type(doc.sents))
print(type(doc[0]))
# Out:
# <class 'spacy.tokens.doc.Doc'>
# <class '_cython_3_1_1.generator'>
# <class 'spacy.tokens.token.Token'>

# %%
# we can create a span
span = doc[3:7]
print(span)
print(type(span))
# Out:
# Maintenance required for HVAC
# <class 'spacy.tokens.span.Span'>

# %%
# checking attributes and methods of an object Token
token = doc[3]
dir(token)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
#  'is_punct',
#  'is_quote',
#  'is_right_punct',
#  'is_sent_end',
#  'is_sent_start',
#  'is_space',
#  'is_stop',
#  'is_title',
#  'is_upper',
#  'lang',
#  'lang_',
#  'left_edge',
#  'lefts',
#  'lemma',
#  'lemma_',
#  'lex',
#  'lex_id',
#  'like_email',
#  'like_num',
#  'like_url',
#  'lower',
#  'lower_',
#  'morph',
#  'n_lefts',
#  'n_rights',
#  'nbor',
#  'norm',
#  'norm_',
#  'orth',
#  'orth_',
#  'pos',
#  'pos_',
#  'prefix',
#  'prefix_',
#  'prob',
#  'rank',
#  'remove_extension',
#  'right_edge',
#  'rights',
#  'sent',
#  'sent_start',
#  'sentiment',
#  'set_extension',
#  'set_morph',
#  'shape',
#  'shape_',
#  'similarity',
#  'subtree',
#  'suffix',
#  'suffix_',
#  'tag',
#  'tag_',
#  'tensor',
#  'text',
#  'text_with_ws',
#  'vector',
#  'vector_norm',
#  'vocab',
#  'whitespace_']

# %%
# checking if the token is alphabetic
print('Is the token alphabetic?')
print(token.is_alpha)

# checking if the token is numeric
print('Is the token numeric?')
print(token.is_digit)

# checking if the token is a space
print('Is the token a space?')
print(token.is_space)

# checking the part of speech tag
print('Part of speech tag:')
print(token.pos_)

# checking the dependency label
print('Dependency label:')
print(token.dep_)

# checking the lemma of the token
print('Lemma:')
print(token.lemma_)

# checking the shape of the token
print('Shape:')
print(token.shape_)

# checking the prefix of the token
print('Prefix:')
print(token.prefix_)

# checking the suffix of the token
print('Suffix:')
print(token.suffix_)
# Out:
# Is the token alphabetic?
# True
# Is the token numeric?
# False
# Is the token a space?
# False
# Part of speech tag:
# PROPN
# Dependency label:
# nsubj
# Lemma:
# Maintenance
# Shape:
# Xxxxx
# Prefix:
# M
# Suffix:
# nce

# %%
for token in doc:
    print(f'Token: {token.text}, POS: {token.pos_}, Dependency: {token.dep_}, Lemma: {token.lemma_}')
    print(f'Is alpha: {token.is_alpha}, Index: {token.i}, Is punctuation: {token.is_punct}, Like num: {token.like_num}, Is currency: {token.is_currency}')
# Out:
# Token: Work, POS: NOUN, Dependency: compound, Lemma: work
# Is alpha: True, Index: 0, Is punctuation: False, Like num: False, Is currency: False
# Token: Order, POS: NOUN, Dependency: ROOT, Lemma: order
# Is alpha: True, Index: 1, Is punctuation: False, Like num: False, Is currency: False
# Token: :, POS: PUNCT, Dependency: punct, Lemma: :
# Is alpha: False, Index: 2, Is punctuation: True, Like num: False, Is currency: False
# Token: Maintenance, POS: PROPN, Dependency: nsubj, Lemma: Maintenance
# Is alpha: True, Index: 3, Is punctuation: False, Like num: False, Is currency: False
# Token: required, POS: VERB, Dependency: acl, Lemma: require
# Is alpha: True, Index: 4, Is punctuation: False, Like num: False, Is currency: False
# Token: for, POS: ADP, Dependency: prep, Lemma: for
# Is alpha: True, Index: 5, Is punctuation: False, Like num: False, Is currency: False
# Token: HVAC, POS: PROPN, Dependency: compound, Lemma: HVAC
# Is alpha: True, Index: 6, Is punctuation: False, Like num: False, Is currency: False
# Token: system, POS: NOUN, Dependency: pobj, Lemma: system
# Is alpha: True, Index: 7, Is punctuation: False, Like num: False, Is currency: False
# Token: in, POS: ADP, Dependency: prep, Lemma: in
# Is alpha: True, Index: 8, Is punctuation: False, Like num: False, Is currency: False
# Token: Building, POS: PROPN, Dependency: compound, Lemma: Building
# Is alpha: True, Index: 9, Is punctuation: False, Like num: False, Is currency: False
# Token: A., POS: PROPN, Dependency: compound, Lemma: A.
# Is alpha: False, Index: 10, Is punctuation: False, Like num: False, Is currency: False
# Token: Priority, POS: PROPN, Dependency: pobj, Lemma: Priority
# Is alpha: True, Index: 11, Is punctuation: False, Like num: False, Is currency: False
# Token: :, POS: PUNCT, Dependency: punct, Lemma: :
# Is alpha: False, Index: 12, Is punctuation: True, Like num: False, Is currency: False
# Token: High, POS: NOUN, Dependency: appos, Lemma: high
# Is alpha: True, Index: 13, Is punctuation: False, Like num: False, Is currency: False
# Token: ., POS: PUNCT, Dependency: punct, Lemma: .
# Is alpha: False, Index: 14, Is punctuation: True, Like num: False, Is currency: False
# Token: Assigned, POS: VERB, Dependency: ROOT, Lemma: assign
# Is alpha: True, Index: 15, Is punctuation: False, Like num: False, Is currency: False
# Token: to, POS: ADP, Dependency: prep, Lemma: to
# Is alpha: True, Index: 16, Is punctuation: False, Like num: False, Is currency: False
# Token: :, POS: PUNCT, Dependency: punct, Lemma: :
# Is alpha: False, Index: 17, Is punctuation: True, Like num: False, Is currency: False
# Token: John, POS: PROPN, Dependency: compound, Lemma: John
# Is alpha: True, Index: 18, Is punctuation: False, Like num: False, Is currency: False
# Token: Doe, POS: PROPN, Dependency: nsubj, Lemma: Doe
# Is alpha: True, Index: 19, Is punctuation: False, Like num: False, Is currency: False
# Token: ., POS: PUNCT, Dependency: punct, Lemma: .
# Is alpha: False, Index: 20, Is punctuation: True, Like num: False, Is currency: False

# %%
import random

# Generate a long list of names, emails, and departments
names = ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Hannah", "Ivy", "Jack"]
domains = ["example.com", "company.org", "industry.net", "business.io"]
departments = ["HR", "Finance", "Engineering", "Marketing", "Sales", "IT", "Operations"]

# Create a string simulating a text file
text_file_content = ""
for i in range(501):  # Generate 501 entries
    name = random.choice(names)
    email = f"{name.lower()}{i}@{random.choice(domains)}"
    dept = random.choice(departments)
    text_file_content += f"{name}\t{email}\t{dept}\n"

# Print the simulated text file content
print(text_file_content)
# Out:
# Bob	bob0@example.com	Engineering
# Frank	frank1@company.org	Operations
# Bob	bob2@business.io	Engineering
# Jack	jack3@industry.net	Engineering
# David	david4@industry.net	Engineering
# Eve	eve5@business.io	HR
# Alice	alice6@company.org	Engineering
# Bob	bob7@example.com	Finance
# Hannah	hannah8@example.com	Engineering
# Grace	grace9@business.io	Sales
# Jack	jack10@company.org	Finance
# David	david11@example.com	Engineering
# Jack	jack12@example.com	Engineering
# Alice	alice13@business.io	HR
# Grace	grace14@company.org	Sales
# Alice	alice15@company.org	Operations
# Eve	eve16@example.com	Marketing
# Ivy	ivy17@example.com	Operations
# David	david18@example.com	Sales
# Jack	jack19@industry.net	HR
# Charlie	charlie20@industry.net	Marketing
# Bob	bob21@business.io	HR
# Jack	jack22@example.com	Marketing
# David	david23@business.io	IT
# Grace	grace24@example.com	Marketing
# Bob	bob25@example.com	HR
# Hannah	hannah26@business.io	Engineering
# Eve	eve27@industry.net	Marketing
# Eve	eve28@business.io	HR
# Charlie	charlie29@example.com	Operations
# Eve	eve30@company.org	HR
# Charlie	charlie31@business.io	Sales
# Eve	eve32@company.org	Operations
# Bob	bob33@business.io	Operations
# Ivy	ivy34@example.com	HR
# Grace	grace35@example.com	Operations
# Alice	alice36@company.org	HR
# David	david37@business.io	Marketing
# Eve	eve38@industry.net	Engineering
# Ivy	ivy39@business.io	Engineering
# Frank	frank40@business.io	Marketing
# Bob	bob41@example.com	IT
# David	david42@business.io	Operations
# Grace	grace43@example.com	Sales
# Hannah	hannah44@example.com	Marketing
# Charlie	charlie45@business.io	IT
# Jack	jack46@company.org	HR
# Charlie	charlie47@industry.net	Marketing
# Eve	eve48@industry.net	Operations
# Hannah	hannah49@example.com	IT
# Bob	bob50@example.com	Sales
# Charlie	charlie51@example.com	Engineering
# Jack	jack52@example.com	Finance
# Eve	eve53@business.io	Marketing
# Frank	frank54@industry.net	Marketing
# Hannah	hannah55@company.org	IT
# Ivy	ivy56@industry.net	IT
# Jack	jack57@business.io	Marketing
# Charlie	charlie58@industry.net	Sales
# Eve	eve59@example.com	Engineering
# Eve	eve60@company.org	IT
# Frank	frank61@example.com	HR
# David	david62@industry.net	Sales
# Bob	bob63@business.io	IT
# Frank	frank64@business.io	HR
# Eve	eve65@industry.net	Finance
# David	david66@example.com	Engineering
# Hannah	hannah67@industry.net	Marketing
# Alice	alice68@company.org	Finance
# Alice	alice69@industry.net	Sales
# Grace	grace70@industry.net	Marketing
# Bob	bob71@company.org	Operations
# Grace	grace72@company.org	Operations
# Alice	alice73@company.org	Finance
# Frank	frank74@business.io	Finance
# Alice	alice75@industry.net	Finance
# Alice	alice76@company.org	HR
# Grace	grace77@company.org	Engineering
# Alice	alice78@example.com	Finance
# Eve	eve79@example.com	Marketing
# Bob	bob80@industry.net	HR
# Hannah	hannah81@company.org	Finance
# Eve	eve82@example.com	IT
# Alice	alice83@example.com	Marketing
# Jack	jack84@company.org	IT
# Bob	bob85@company.org	Engineering
# David	david86@business.io	Engineering
# Charlie	charlie87@business.io	Engineering
# Jack	jack88@example.com	IT
# Frank	frank89@business.io	HR
# Eve	eve90@business.io	Operations
# Alice	alice91@example.com	Sales
# David	david92@industry.net	Operations
# Alice	alice93@business.io	Operations
# Jack	jack94@company.org	IT
# Hannah	hannah95@business.io	HR
# Charlie	charlie96@business.io	Engineering
# Hannah	hannah97@business.io	HR
# Charlie	charlie98@company.org	Operations
# Ivy	ivy99@company.org	IT
# Bob	bob100@example.com	IT
# Alice	alice101@business.io	HR
# Eve	eve102@example.com	IT
# Frank	frank103@example.com	Marketing
# Alice	alice104@example.com	Finance
# Bob	bob105@business.io	Sales
# Eve	eve106@example.com	Engineering
# Bob	bob107@industry.net	Engineering
# Eve	eve108@business.io	HR
# David	david109@example.com	IT
# Ivy	ivy110@industry.net	Marketing
# Eve	eve111@business.io	IT
# David	david112@business.io	Operations
# Frank	frank113@example.com	Sales
# Charlie	charlie114@business.io	Sales
# Charlie	charlie115@company.org	HR
# Alice	alice116@business.io	Engineering
# Charlie	charlie117@business.io	Sales
# Hannah	hannah118@business.io	Engineering
# Ivy	ivy119@company.org	HR
# Jack	jack120@company.org	Sales
# Bob	bob121@industry.net	Marketing
# Frank	frank122@business.io	Sales
# Charlie	charlie123@business.io	Engineering
# Jack	jack124@example.com	Sales
# Eve	eve125@business.io	Engineering
# Ivy	ivy126@industry.net	Operations
# Hannah	hannah127@company.org	Engineering
# Alice	alice128@industry.net	Engineering
# Frank	frank129@company.org	Operations
# Hannah	hannah130@industry.net	Sales
# Frank	frank131@industry.net	Marketing
# Hannah	hannah132@company.org	IT
# Grace	grace133@business.io	Finance
# Charlie	charlie134@business.io	Marketing
# Charlie	charlie135@business.io	Marketing
# Alice	alice136@business.io	Engineering
# Alice	alice137@company.org	IT
# Alice	alice138@industry.net	Engineering
# Bob	bob139@industry.net	Engineering
# Hannah	hannah140@industry.net	Engineering
# Frank	frank141@business.io	Operations
# Eve	eve142@industry.net	Operations
# David	david143@example.com	HR
# Ivy	ivy144@business.io	Engineering
# Alice	alice145@industry.net	Operations
# Alice	alice146@business.io	Finance
# Charlie	charlie147@business.io	Marketing
# Eve	eve148@example.com	Finance
# Eve	eve149@example.com	Engineering
# David	david150@company.org	Finance
# Charlie	charlie151@business.io	HR
# David	david152@company.org	Engineering
# Ivy	ivy153@example.com	Marketing
# Eve	eve154@industry.net	Operations
# Eve	eve155@industry.net	HR
# Charlie	charlie156@company.org	Engineering
# Grace	grace157@industry.net	Engineering
# Frank	frank158@example.com	IT
# Alice	alice159@industry.net	Operations
# Frank	frank160@business.io	Operations
# Charlie	charlie161@industry.net	Finance
# Charlie	charlie162@business.io	Marketing
# Charlie	charlie163@example.com	Marketing
# David	david164@business.io	Finance
# Frank	frank165@company.org	Marketing
# Ivy	ivy166@company.org	HR
# Grace	grace167@business.io	HR
# Charlie	charlie168@business.io	Finance
# Frank	frank169@example.com	IT
# Ivy	ivy170@company.org	Engineering
# David	david171@industry.net	Operations
# Hannah	hannah172@company.org	HR
# David	david173@company.org	Operations
# Eve	eve174@business.io	Finance
# Alice	alice175@example.com	Marketing
# Frank	frank176@company.org	Sales
# Grace	grace177@company.org	Sales
# Bob	bob178@industry.net	HR
# Frank	frank179@company.org	Sales
# Alice	alice180@company.org	Operations
# Alice	alice181@industry.net	Engineering
# David	david182@company.org	Operations
# Alice	alice183@example.com	Operations
# Frank	frank184@company.org	Engineering
# Ivy	ivy185@business.io	Finance
# Grace	grace186@industry.net	Finance
# Ivy	ivy187@company.org	Engineering
# Frank	frank188@business.io	Sales
# Frank	frank189@example.com	Operations
# Ivy	ivy190@industry.net	IT
# Hannah	hannah191@industry.net	Engineering
# Ivy	ivy192@business.io	Engineering
# Hannah	hannah193@company.org	Engineering
# Bob	bob194@example.com	Finance
# Hannah	hannah195@business.io	Sales
# David	david196@example.com	Engineering
# Grace	grace197@company.org	Finance
# Grace	grace198@business.io	Operations
# Ivy	ivy199@company.org	Finance
# Alice	alice200@company.org	Engineering
# David	david201@company.org	Operations
# Ivy	ivy202@business.io	Engineering
# Eve	eve203@company.org	Operations
# Bob	bob204@industry.net	Marketing
# Grace	grace205@industry.net	IT
# Bob	bob206@example.com	Operations
# Hannah	hannah207@business.io	Marketing
# Ivy	ivy208@example.com	Finance
# Hannah	hannah209@company.org	Finance
# Charlie	charlie210@company.org	Engineering
# Alice	alice211@business.io	Engineering
# Charlie	charlie212@business.io	Engineering
# Bob	bob213@example.com	HR
# Frank	frank214@industry.net	Finance
# Alice	alice215@business.io	IT
# Jack	jack216@industry.net	Finance
# Ivy	ivy217@business.io	IT
# Charlie	charlie218@industry.net	Operations
# Bob	bob219@company.org	IT
# Ivy	ivy220@company.org	HR
# Alice	alice221@company.org	Marketing
# Hannah	hannah222@company.org	Finance
# Hannah	hannah223@industry.net	Sales
# David	david224@company.org	Marketing
# Grace	grace225@industry.net	HR
# Grace	grace226@industry.net	Finance
# Frank	frank227@example.com	IT
# Charlie	charlie228@industry.net	Sales
# Charlie	charlie229@company.org	Sales
# Jack	jack230@example.com	Finance
# Bob	bob231@business.io	Engineering
# Ivy	ivy232@example.com	HR
# Hannah	hannah233@industry.net	Finance
# Frank	frank234@industry.net	IT
# Eve	eve235@example.com	Engineering
# Ivy	ivy236@business.io	Operations
# David	david237@industry.net	Engineering
# Frank	frank238@industry.net	Finance
# Grace	grace239@industry.net	Engineering
# Jack	jack240@industry.net	Operations
# Jack	jack241@business.io	Operations
# Charlie	charlie242@business.io	Sales
# Charlie	charlie243@example.com	Marketing
# Jack	jack244@company.org	Engineering
# Ivy	ivy245@industry.net	Marketing
# Frank	frank246@business.io	HR
# Grace	grace247@industry.net	IT
# Eve	eve248@example.com	HR
# Hannah	hannah249@company.org	Finance
# Ivy	ivy250@business.io	Sales
# Bob	bob251@example.com	Operations
# Grace	grace252@company.org	Sales
# Hannah	hannah253@company.org	Operations
# David	david254@business.io	Sales
# David	david255@business.io	Marketing
# Hannah	hannah256@industry.net	Finance
# Frank	frank257@business.io	Sales
# Eve	eve258@example.com	Marketing
# Frank	frank259@industry.net	Finance
# Hannah	hannah260@business.io	IT
# Hannah	hannah261@industry.net	Engineering
# Ivy	ivy262@example.com	HR
# Alice	alice263@industry.net	Marketing
# Jack	jack264@business.io	Operations
# Alice	alice265@business.io	IT
# Frank	frank266@business.io	HR
# Hannah	hannah267@industry.net	Engineering
# Alice	alice268@company.org	Engineering
# Ivy	ivy269@industry.net	Operations
# David	david270@example.com	Sales
# Charlie	charlie271@company.org	Finance
# David	david272@example.com	Engineering
# Ivy	ivy273@example.com	Sales
# Ivy	ivy274@company.org	Sales
# David	david275@company.org	Sales
# Alice	alice276@industry.net	Marketing
# Frank	frank277@industry.net	Sales
# Grace	grace278@company.org	Operations
# Frank	frank279@business.io	Operations
# Bob	bob280@company.org	IT
# Eve	eve281@example.com	Sales
# Eve	eve282@industry.net	Operations
# Ivy	ivy283@industry.net	Marketing
# Hannah	hannah284@industry.net	Sales
# Frank	frank285@business.io	Engineering
# Bob	bob286@industry.net	Operations
# Bob	bob287@industry.net	IT
# Jack	jack288@example.com	Sales
# Bob	bob289@industry.net	Engineering
# Bob	bob290@example.com	HR
# Grace	grace291@company.org	Sales
# Jack	jack292@business.io	Marketing
# Charlie	charlie293@business.io	Sales
# Ivy	ivy294@company.org	HR
# Eve	eve295@industry.net	IT
# Bob	bob296@company.org	IT
# Alice	alice297@business.io	Operations
# David	david298@business.io	Finance
# Jack	jack299@example.com	Finance
# David	david300@industry.net	Engineering
# David	david301@business.io	Finance
# Alice	alice302@company.org	Engineering
# Bob	bob303@industry.net	Marketing
# Charlie	charlie304@example.com	Finance
# Jack	jack305@example.com	Sales
# Alice	alice306@example.com	HR
# Hannah	hannah307@company.org	Operations
# Ivy	ivy308@example.com	IT
# Alice	alice309@company.org	Marketing
# Jack	jack310@company.org	Marketing
# Alice	alice311@example.com	Finance
# Grace	grace312@company.org	Operations
# Ivy	ivy313@business.io	Engineering
# Grace	grace314@business.io	IT
# Frank	frank315@business.io	IT
# Ivy	ivy316@business.io	Engineering
# Alice	alice317@company.org	Marketing
# Hannah	hannah318@industry.net	Finance
# Eve	eve319@example.com	IT
# Hannah	hannah320@company.org	IT
# Frank	frank321@industry.net	Marketing
# Frank	frank322@company.org	Engineering
# Eve	eve323@company.org	Engineering
# Alice	alice324@business.io	HR
# Eve	eve325@business.io	IT
# David	david326@business.io	IT
# Ivy	ivy327@business.io	Sales
# Charlie	charlie328@industry.net	Finance
# Charlie	charlie329@company.org	HR
# Jack	jack330@industry.net	Finance
# Charlie	charlie331@business.io	Marketing
# Hannah	hannah332@company.org	Sales
# Charlie	charlie333@business.io	Engineering
# Bob	bob334@company.org	IT
# Hannah	hannah335@industry.net	Sales
# Hannah	hannah336@business.io	Operations
# Ivy	ivy337@industry.net	Operations
# Hannah	hannah338@company.org	Marketing
# Grace	grace339@example.com	HR
# Frank	frank340@example.com	IT
# Charlie	charlie341@business.io	Marketing
# Hannah	hannah342@business.io	Engineering
# Charlie	charlie343@example.com	IT
# Alice	alice344@industry.net	Marketing
# Hannah	hannah345@industry.net	Finance
# Bob	bob346@company.org	Operations
# David	david347@company.org	IT
# Charlie	charlie348@business.io	IT
# Grace	grace349@business.io	Marketing
# Jack	jack350@business.io	Engineering
# Grace	grace351@business.io	Engineering
# Eve	eve352@example.com	Operations
# Eve	eve353@example.com	Sales
# David	david354@business.io	Finance
# Ivy	ivy355@company.org	Sales
# Alice	alice356@industry.net	Engineering
# David	david357@example.com	IT
# Jack	jack358@business.io	Marketing
# David	david359@company.org	IT
# Hannah	hannah360@example.com	Sales
# Bob	bob361@business.io	Finance
# Eve	eve362@industry.net	IT
# Alice	alice363@example.com	Finance
# Frank	frank364@business.io	Sales
# Eve	eve365@company.org	Finance
# Hannah	hannah366@company.org	Operations
# Hannah	hannah367@company.org	Finance
# Frank	frank368@example.com	Finance
# Bob	bob369@company.org	IT
# Eve	eve370@example.com	Finance
# Charlie	charlie371@industry.net	Finance
# David	david372@company.org	Finance
# Eve	eve373@example.com	Sales
# Charlie	charlie374@industry.net	IT
# Grace	grace375@business.io	IT
# Grace	grace376@business.io	Marketing
# Frank	frank377@example.com	Marketing
# Grace	grace378@company.org	Marketing
# David	david379@example.com	IT
# Jack	jack380@example.com	Marketing
# Eve	eve381@industry.net	Operations
# Jack	jack382@business.io	Sales
# Hannah	hannah383@example.com	Operations
# Eve	eve384@company.org	Operations
# Alice	alice385@company.org	Finance
# Charlie	charlie386@example.com	Engineering
# Jack	jack387@company.org	Engineering
# David	david388@industry.net	Marketing
# Frank	frank389@company.org	Sales
# Grace	grace390@industry.net	Finance
# Ivy	ivy391@business.io	Engineering
# David	david392@industry.net	Sales
# Jack	jack393@example.com	IT
# Alice	alice394@company.org	Sales
# Hannah	hannah395@industry.net	Marketing
# Frank	frank396@industry.net	Engineering
# Jack	jack397@company.org	Operations
# Alice	alice398@company.org	Operations
# Grace	grace399@business.io	Engineering
# Ivy	ivy400@business.io	Marketing
# Frank	frank401@business.io	Marketing
# Alice	alice402@business.io	Finance
# Ivy	ivy403@company.org	Engineering
# Jack	jack404@business.io	Sales
# Grace	grace405@example.com	IT
# Frank	frank406@industry.net	HR
# Charlie	charlie407@example.com	Sales
# Alice	alice408@business.io	Engineering
# David	david409@industry.net	Engineering
# Alice	alice410@company.org	Marketing
# Grace	grace411@industry.net	IT
# Eve	eve412@business.io	Engineering
# Grace	grace413@company.org	Marketing
# Frank	frank414@business.io	HR
# Charlie	charlie415@business.io	Finance
# Frank	frank416@business.io	Engineering
# Eve	eve417@business.io	Engineering
# Grace	grace418@example.com	Sales
# Eve	eve419@business.io	IT
# Frank	frank420@example.com	Finance
# Hannah	hannah421@example.com	Marketing
# Ivy	ivy422@example.com	Marketing
# Frank	frank423@company.org	IT
# Hannah	hannah424@example.com	Operations
# David	david425@business.io	Engineering
# Hannah	hannah426@business.io	HR
# Eve	eve427@industry.net	Sales
# Jack	jack428@company.org	IT
# Jack	jack429@company.org	Engineering
# Hannah	hannah430@business.io	HR
# Jack	jack431@example.com	Finance
# David	david432@industry.net	HR
# Hannah	hannah433@industry.net	Finance
# Ivy	ivy434@business.io	Sales
# Bob	bob435@business.io	Marketing
# Ivy	ivy436@company.org	Sales
# Bob	bob437@company.org	IT
# Ivy	ivy438@industry.net	IT
# Jack	jack439@industry.net	IT
# Charlie	charlie440@industry.net	Finance
# Eve	eve441@company.org	Sales
# Jack	jack442@business.io	IT
# Grace	grace443@company.org	Operations
# David	david444@business.io	HR
# Ivy	ivy445@industry.net	Operations
# Charlie	charlie446@business.io	HR
# Bob	bob447@example.com	Sales
# Frank	frank448@example.com	Marketing
# Grace	grace449@company.org	IT
# Charlie	charlie450@business.io	Finance
# Charlie	charlie451@business.io	Operations
# David	david452@business.io	Operations
# Bob	bob453@example.com	Finance
# Alice	alice454@company.org	IT
# Alice	alice455@business.io	Sales
# Grace	grace456@business.io	Finance
# Grace	grace457@industry.net	Engineering
# Alice	alice458@business.io	HR
# Alice	alice459@business.io	Marketing
# Alice	alice460@company.org	Operations
# David	david461@example.com	Operations
# Bob	bob462@industry.net	IT
# Alice	alice463@company.org	Operations
# Jack	jack464@industry.net	IT
# Eve	eve465@industry.net	Operations
# Bob	bob466@business.io	Engineering
# Eve	eve467@industry.net	Engineering
# Charlie	charlie468@example.com	Finance
# Grace	grace469@business.io	Marketing
# Frank	frank470@company.org	IT
# Grace	grace471@example.com	Operations
# Alice	alice472@example.com	HR
# David	david473@industry.net	Operations
# Jack	jack474@example.com	Operations
# Eve	eve475@business.io	Sales
# Bob	bob476@industry.net	Operations
# David	david477@company.org	IT
# Charlie	charlie478@company.org	Marketing
# Alice	alice479@industry.net	HR
# Hannah	hannah480@company.org	IT
# Hannah	hannah481@industry.net	Engineering
# Bob	bob482@company.org	HR
# Charlie	charlie483@company.org	Finance
# Alice	alice484@industry.net	Finance
# Eve	eve485@business.io	Marketing
# Bob	bob486@example.com	Sales
# Charlie	charlie487@business.io	Operations
# Grace	grace488@industry.net	Sales
# Frank	frank489@example.com	Sales
# Grace	grace490@business.io	HR
# Charlie	charlie491@example.com	Finance
# Hannah	hannah492@business.io	Sales
# Hannah	hannah493@company.org	Engineering
# Ivy	ivy494@industry.net	Operations
# Charlie	charlie495@company.org	Finance
# Hannah	hannah496@example.com	Marketing
# Charlie	charlie497@company.org	Marketing
# Hannah	hannah498@example.com	Finance
# Charlie	charlie499@example.com	Sales
# David	david500@example.com	Engineering

# %%
# create a spaCy document from the text file content
doc = nlp(text_file_content)

# printing emails only
for token in doc:
    if token.like_email:
        print(token.text)
# Out:
# bob0@example.com
# frank1@company.org
# bob2@business.io
# jack3@industry.net
# david4@industry.net
# eve5@business.io
# alice6@company.org
# bob7@example.com
# hannah8@example.com
# grace9@business.io
# jack10@company.org
# david11@example.com
# jack12@example.com
# alice13@business.io
# grace14@company.org
# alice15@company.org
# eve16@example.com
# ivy17@example.com
# david18@example.com
# jack19@industry.net
# charlie20@industry.net
# bob21@business.io
# jack22@example.com
# david23@business.io
# grace24@example.com
# bob25@example.com
# hannah26@business.io
# eve27@industry.net
# eve28@business.io
# charlie29@example.com
# eve30@company.org
# charlie31@business.io
# eve32@company.org
# bob33@business.io
# ivy34@example.com
# grace35@example.com
# alice36@company.org
# david37@business.io
# eve38@industry.net
# ivy39@business.io
# frank40@business.io
# bob41@example.com
# david42@business.io
# grace43@example.com
# hannah44@example.com
# charlie45@business.io
# jack46@company.org
# charlie47@industry.net
# eve48@industry.net
# hannah49@example.com
# bob50@example.com
# charlie51@example.com
# jack52@example.com
# eve53@business.io
# frank54@industry.net
# hannah55@company.org
# ivy56@industry.net
# jack57@business.io
# charlie58@industry.net
# eve59@example.com
# eve60@company.org
# frank61@example.com
# david62@industry.net
# bob63@business.io
# frank64@business.io
# eve65@industry.net
# david66@example.com
# hannah67@industry.net
# alice68@company.org
# alice69@industry.net
# grace70@industry.net
# bob71@company.org
# grace72@company.org
# alice73@company.org
# frank74@business.io
# alice75@industry.net
# alice76@company.org
# grace77@company.org
# alice78@example.com
# eve79@example.com
# bob80@industry.net
# hannah81@company.org
# eve82@example.com
# alice83@example.com
# jack84@company.org
# bob85@company.org
# david86@business.io
# charlie87@business.io
# jack88@example.com
# frank89@business.io
# eve90@business.io
# alice91@example.com
# david92@industry.net
# alice93@business.io
# jack94@company.org
# hannah95@business.io
# charlie96@business.io
# hannah97@business.io
# charlie98@company.org
# ivy99@company.org
# bob100@example.com
# alice101@business.io
# eve102@example.com
# frank103@example.com
# alice104@example.com
# bob105@business.io
# eve106@example.com
# bob107@industry.net
# eve108@business.io
# david109@example.com
# ivy110@industry.net
# eve111@business.io
# david112@business.io
# frank113@example.com
# charlie114@business.io
# charlie115@company.org
# alice116@business.io
# charlie117@business.io
# hannah118@business.io
# ivy119@company.org
# jack120@company.org
# bob121@industry.net
# frank122@business.io
# charlie123@business.io
# jack124@example.com
# eve125@business.io
# ivy126@industry.net
# hannah127@company.org
# alice128@industry.net
# frank129@company.org
# hannah130@industry.net
# frank131@industry.net
# hannah132@company.org
# grace133@business.io
# charlie134@business.io
# charlie135@business.io
# alice136@business.io
# alice137@company.org
# alice138@industry.net
# bob139@industry.net
# hannah140@industry.net
# frank141@business.io
# eve142@industry.net
# david143@example.com
# ivy144@business.io
# alice145@industry.net
# alice146@business.io
# charlie147@business.io
# eve148@example.com
# eve149@example.com
# david150@company.org
# charlie151@business.io
# david152@company.org
# ivy153@example.com
# eve154@industry.net
# eve155@industry.net
# charlie156@company.org
# grace157@industry.net
# frank158@example.com
# alice159@industry.net
# frank160@business.io
# charlie161@industry.net
# charlie162@business.io
# charlie163@example.com
# david164@business.io
# frank165@company.org
# ivy166@company.org
# grace167@business.io
# charlie168@business.io
# frank169@example.com
# ivy170@company.org
# david171@industry.net
# hannah172@company.org
# david173@company.org
# eve174@business.io
# alice175@example.com
# frank176@company.org
# grace177@company.org
# bob178@industry.net
# frank179@company.org
# alice180@company.org
# alice181@industry.net
# david182@company.org
# alice183@example.com
# frank184@company.org
# ivy185@business.io
# grace186@industry.net
# ivy187@company.org
# frank188@business.io
# frank189@example.com
# ivy190@industry.net
# hannah191@industry.net
# ivy192@business.io
# hannah193@company.org
# bob194@example.com
# hannah195@business.io
# david196@example.com
# grace197@company.org
# grace198@business.io
# ivy199@company.org
# alice200@company.org
# david201@company.org
# ivy202@business.io
# eve203@company.org
# bob204@industry.net
# grace205@industry.net
# bob206@example.com
# hannah207@business.io
# ivy208@example.com
# hannah209@company.org
# charlie210@company.org
# alice211@business.io
# charlie212@business.io
# bob213@example.com
# frank214@industry.net
# alice215@business.io
# jack216@industry.net
# ivy217@business.io
# charlie218@industry.net
# bob219@company.org
# ivy220@company.org
# alice221@company.org
# hannah222@company.org
# hannah223@industry.net
# david224@company.org
# grace225@industry.net
# grace226@industry.net
# frank227@example.com
# charlie228@industry.net
# charlie229@company.org
# jack230@example.com
# bob231@business.io
# ivy232@example.com
# hannah233@industry.net
# frank234@industry.net
# eve235@example.com
# ivy236@business.io
# david237@industry.net
# frank238@industry.net
# grace239@industry.net
# jack240@industry.net
# jack241@business.io
# charlie242@business.io
# charlie243@example.com
# jack244@company.org
# ivy245@industry.net
# frank246@business.io
# grace247@industry.net
# eve248@example.com
# hannah249@company.org
# ivy250@business.io
# bob251@example.com
# grace252@company.org
# hannah253@company.org
# david254@business.io
# david255@business.io
# hannah256@industry.net
# frank257@business.io
# eve258@example.com
# frank259@industry.net
# hannah260@business.io
# hannah261@industry.net
# ivy262@example.com
# alice263@industry.net
# jack264@business.io
# alice265@business.io
# frank266@business.io
# hannah267@industry.net
# alice268@company.org
# ivy269@industry.net
# david270@example.com
# charlie271@company.org
# david272@example.com
# ivy273@example.com
# ivy274@company.org
# david275@company.org
# alice276@industry.net
# frank277@industry.net
# grace278@company.org
# frank279@business.io
# bob280@company.org
# eve281@example.com
# eve282@industry.net
# ivy283@industry.net
# hannah284@industry.net
# frank285@business.io
# bob286@industry.net
# bob287@industry.net
# jack288@example.com
# bob289@industry.net
# bob290@example.com
# grace291@company.org
# jack292@business.io
# charlie293@business.io
# ivy294@company.org
# eve295@industry.net
# bob296@company.org
# alice297@business.io
# david298@business.io
# jack299@example.com
# david300@industry.net
# david301@business.io
# alice302@company.org
# bob303@industry.net
# charlie304@example.com
# jack305@example.com
# alice306@example.com
# hannah307@company.org
# ivy308@example.com
# alice309@company.org
# jack310@company.org
# alice311@example.com
# grace312@company.org
# ivy313@business.io
# grace314@business.io
# frank315@business.io
# ivy316@business.io
# alice317@company.org
# hannah318@industry.net
# eve319@example.com
# hannah320@company.org
# frank321@industry.net
# frank322@company.org
# eve323@company.org
# alice324@business.io
# eve325@business.io
# david326@business.io
# ivy327@business.io
# charlie328@industry.net
# charlie329@company.org
# jack330@industry.net
# charlie331@business.io
# hannah332@company.org
# charlie333@business.io
# bob334@company.org
# hannah335@industry.net
# hannah336@business.io
# ivy337@industry.net
# hannah338@company.org
# grace339@example.com
# frank340@example.com
# charlie341@business.io
# hannah342@business.io
# charlie343@example.com
# alice344@industry.net
# hannah345@industry.net
# bob346@company.org
# david347@company.org
# charlie348@business.io
# grace349@business.io
# jack350@business.io
# grace351@business.io
# eve352@example.com
# eve353@example.com
# david354@business.io
# ivy355@company.org
# alice356@industry.net
# david357@example.com
# jack358@business.io
# david359@company.org
# hannah360@example.com
# bob361@business.io
# eve362@industry.net
# alice363@example.com
# frank364@business.io
# eve365@company.org
# hannah366@company.org
# hannah367@company.org
# frank368@example.com
# bob369@company.org
# eve370@example.com
# charlie371@industry.net
# david372@company.org
# eve373@example.com
# charlie374@industry.net
# grace375@business.io
# grace376@business.io
# frank377@example.com
# grace378@company.org
# david379@example.com
# jack380@example.com
# eve381@industry.net
# jack382@business.io
# hannah383@example.com
# eve384@company.org
# alice385@company.org
# charlie386@example.com
# jack387@company.org
# david388@industry.net
# frank389@company.org
# grace390@industry.net
# ivy391@business.io
# david392@industry.net
# jack393@example.com
# alice394@company.org
# hannah395@industry.net
# frank396@industry.net
# jack397@company.org
# alice398@company.org
# grace399@business.io
# ivy400@business.io
# frank401@business.io
# alice402@business.io
# ivy403@company.org
# jack404@business.io
# grace405@example.com
# frank406@industry.net
# charlie407@example.com
# alice408@business.io
# david409@industry.net
# alice410@company.org
# grace411@industry.net
# eve412@business.io
# grace413@company.org
# frank414@business.io
# charlie415@business.io
# frank416@business.io
# eve417@business.io
# grace418@example.com
# eve419@business.io
# frank420@example.com
# hannah421@example.com
# ivy422@example.com
# frank423@company.org
# hannah424@example.com
# david425@business.io
# hannah426@business.io
# eve427@industry.net
# jack428@company.org
# jack429@company.org
# hannah430@business.io
# jack431@example.com
# david432@industry.net
# hannah433@industry.net
# ivy434@business.io
# bob435@business.io
# ivy436@company.org
# bob437@company.org
# ivy438@industry.net
# jack439@industry.net
# charlie440@industry.net
# eve441@company.org
# jack442@business.io
# grace443@company.org
# david444@business.io
# ivy445@industry.net
# charlie446@business.io
# bob447@example.com
# frank448@example.com
# grace449@company.org
# charlie450@business.io
# charlie451@business.io
# david452@business.io
# bob453@example.com
# alice454@company.org
# alice455@business.io
# grace456@business.io
# grace457@industry.net
# alice458@business.io
# alice459@business.io
# alice460@company.org
# david461@example.com
# bob462@industry.net
# alice463@company.org
# jack464@industry.net
# eve465@industry.net
# bob466@business.io
# eve467@industry.net
# charlie468@example.com
# grace469@business.io
# frank470@company.org
# grace471@example.com
# alice472@example.com
# david473@industry.net
# jack474@example.com
# eve475@business.io
# bob476@industry.net
# david477@company.org
# charlie478@company.org
# alice479@industry.net
# hannah480@company.org
# hannah481@industry.net
# bob482@company.org
# charlie483@company.org
# alice484@industry.net
# eve485@business.io
# bob486@example.com
# charlie487@business.io
# grace488@industry.net
# frank489@example.com
# grace490@business.io
# charlie491@example.com
# hannah492@business.io
# hannah493@company.org
# ivy494@industry.net
# charlie495@company.org
# hannah496@example.com
# charlie497@company.org
# hannah498@example.com
# charlie499@example.com
# david500@example.com

# %%
# now lets get the emails only if the department is Engineering
emails_for_wo = []
for line in text_file_content.split('\n'):
    parts = line.split('\t')
    if len(parts) == 3:
        name, email, dept = parts
        if dept == "Engineering":
            print(f"Name: {name}, Email: {email}, Department: {dept}")
            emails_for_wo.append(email)
# Out:
# Name: Bob, Email: bob0@example.com, Department: Engineering
# Name: Bob, Email: bob2@business.io, Department: Engineering
# Name: Jack, Email: jack3@industry.net, Department: Engineering
# Name: David, Email: david4@industry.net, Department: Engineering
# Name: Alice, Email: alice6@company.org, Department: Engineering
# Name: Hannah, Email: hannah8@example.com, Department: Engineering
# Name: David, Email: david11@example.com, Department: Engineering
# Name: Jack, Email: jack12@example.com, Department: Engineering
# Name: Hannah, Email: hannah26@business.io, Department: Engineering
# Name: Eve, Email: eve38@industry.net, Department: Engineering
# Name: Ivy, Email: ivy39@business.io, Department: Engineering
# Name: Charlie, Email: charlie51@example.com, Department: Engineering
# Name: Eve, Email: eve59@example.com, Department: Engineering
# Name: David, Email: david66@example.com, Department: Engineering
# Name: Grace, Email: grace77@company.org, Department: Engineering
# Name: Bob, Email: bob85@company.org, Department: Engineering
# Name: David, Email: david86@business.io, Department: Engineering
# Name: Charlie, Email: charlie87@business.io, Department: Engineering
# Name: Charlie, Email: charlie96@business.io, Department: Engineering
# Name: Eve, Email: eve106@example.com, Department: Engineering
# Name: Bob, Email: bob107@industry.net, Department: Engineering
# Name: Alice, Email: alice116@business.io, Department: Engineering
# Name: Hannah, Email: hannah118@business.io, Department: Engineering
# Name: Charlie, Email: charlie123@business.io, Department: Engineering
# Name: Eve, Email: eve125@business.io, Department: Engineering
# Name: Hannah, Email: hannah127@company.org, Department: Engineering
# Name: Alice, Email: alice128@industry.net, Department: Engineering
# Name: Alice, Email: alice136@business.io, Department: Engineering
# Name: Alice, Email: alice138@industry.net, Department: Engineering
# Name: Bob, Email: bob139@industry.net, Department: Engineering
# Name: Hannah, Email: hannah140@industry.net, Department: Engineering
# Name: Ivy, Email: ivy144@business.io, Department: Engineering
# Name: Eve, Email: eve149@example.com, Department: Engineering
# Name: David, Email: david152@company.org, Department: Engineering
# Name: Charlie, Email: charlie156@company.org, Department: Engineering
# Name: Grace, Email: grace157@industry.net, Department: Engineering
# Name: Ivy, Email: ivy170@company.org, Department: Engineering
# Name: Alice, Email: alice181@industry.net, Department: Engineering
# Name: Frank, Email: frank184@company.org, Department: Engineering
# Name: Ivy, Email: ivy187@company.org, Department: Engineering
# Name: Hannah, Email: hannah191@industry.net, Department: Engineering
# Name: Ivy, Email: ivy192@business.io, Department: Engineering
# Name: Hannah, Email: hannah193@company.org, Department: Engineering
# Name: David, Email: david196@example.com, Department: Engineering
# Name: Alice, Email: alice200@company.org, Department: Engineering
# Name: Ivy, Email: ivy202@business.io, Department: Engineering
# Name: Charlie, Email: charlie210@company.org, Department: Engineering
# Name: Alice, Email: alice211@business.io, Department: Engineering
# Name: Charlie, Email: charlie212@business.io, Department: Engineering
# Name: Bob, Email: bob231@business.io, Department: Engineering
# Name: Eve, Email: eve235@example.com, Department: Engineering
# Name: David, Email: david237@industry.net, Department: Engineering
# Name: Grace, Email: grace239@industry.net, Department: Engineering
# Name: Jack, Email: jack244@company.org, Department: Engineering
# Name: Hannah, Email: hannah261@industry.net, Department: Engineering
# Name: Hannah, Email: hannah267@industry.net, Department: Engineering
# Name: Alice, Email: alice268@company.org, Department: Engineering
# Name: David, Email: david272@example.com, Department: Engineering
# Name: Frank, Email: frank285@business.io, Department: Engineering
# Name: Bob, Email: bob289@industry.net, Department: Engineering
# Name: David, Email: david300@industry.net, Department: Engineering
# Name: Alice, Email: alice302@company.org, Department: Engineering
# Name: Ivy, Email: ivy313@business.io, Department: Engineering
# Name: Ivy, Email: ivy316@business.io, Department: Engineering
# Name: Frank, Email: frank322@company.org, Department: Engineering
# Name: Eve, Email: eve323@company.org, Department: Engineering
# Name: Charlie, Email: charlie333@business.io, Department: Engineering
# Name: Hannah, Email: hannah342@business.io, Department: Engineering
# Name: Jack, Email: jack350@business.io, Department: Engineering
# Name: Grace, Email: grace351@business.io, Department: Engineering
# Name: Alice, Email: alice356@industry.net, Department: Engineering
# Name: Charlie, Email: charlie386@example.com, Department: Engineering
# Name: Jack, Email: jack387@company.org, Department: Engineering
# Name: Ivy, Email: ivy391@business.io, Department: Engineering
# Name: Frank, Email: frank396@industry.net, Department: Engineering
# Name: Grace, Email: grace399@business.io, Department: Engineering
# Name: Ivy, Email: ivy403@company.org, Department: Engineering
# Name: Alice, Email: alice408@business.io, Department: Engineering
# Name: David, Email: david409@industry.net, Department: Engineering
# Name: Eve, Email: eve412@business.io, Department: Engineering
# Name: Frank, Email: frank416@business.io, Department: Engineering
# Name: Eve, Email: eve417@business.io, Department: Engineering
# Name: David, Email: david425@business.io, Department: Engineering
# Name: Jack, Email: jack429@company.org, Department: Engineering
# Name: Grace, Email: grace457@industry.net, Department: Engineering
# Name: Bob, Email: bob466@business.io, Department: Engineering
# Name: Eve, Email: eve467@industry.net, Department: Engineering
# Name: Hannah, Email: hannah481@industry.net, Department: Engineering
# Name: Hannah, Email: hannah493@company.org, Department: Engineering
# Name: David, Email: david500@example.com, Department: Engineering

# %%
# tokenizing with nltk
sent_tokenize(work_order)
# Out:
# ['Work Order: Maintenance required for HVAC system in Building A.',
#  'Priority: High.',
#  'Assigned to: John Doe.']

# %%
# word tokenizing with nltk
word_tokenize(work_order)
# Out:
# ['Work',
#  'Order',
#  ':',
#  'Maintenance',
#  'required',
#  'for',
#  'HVAC',
#  'system',
#  'in',
#  'Building',
#  'A',
#  '.',
#  'Priority',
#  ':',
#  'High',
#  '.',
#  'Assigned',
#  'to',
#  ':',
#  'John',
#  'Doe',
#  '.']
