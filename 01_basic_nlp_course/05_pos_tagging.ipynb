# %% [markdown]
# # Basic NLP Course
#
# ## Part-of-Speech (POS) Tagging
#
# Part-of-Speech (POS) tagging is a process in Natural Language Processing (NLP) that involves assigning a part of speech to each word in a text, such as noun, verb, adjective, etc.
#
# - **Definition**: POS tagging helps in understanding the grammatical structure of a sentence and the relationships between words.
# - **Example**: In the sentence "The quick brown fox jumps over the lazy dog," POS tagging assigns:
#     - "The" → Determiner
#     - "quick" → Adjective
#     - "brown" → Adjective
#     - "fox" → Noun
#     - "jumps" → Verb
#     - "over" → Preposition
#     - "the" → Determiner
#     - "lazy" → Adjective
#     - "dog" → Noun

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
qa_report = """
Quality Assurance Analysis and Report
=====================================

Summary:
---------
The quality assurance analysis was conducted to evaluate the performance, reliability, and compliance of the system with the defined standards and requirements.

Findings:
---------
1. Performance:
    - The system meets the performance benchmarks in 85% of the test cases.
    - Identified latency issues in module X during peak load conditions.

2. Reliability:
    - The system demonstrated 99.5% uptime over the evaluation period.
    - A rare edge case caused a crash in module Y.

3. Compliance:
    - The system complies with 95% of the defined standards.
    - Minor deviations were observed in data encryption protocols.

Actions:
---------
1. Optimize module X to handle peak load conditions more efficiently.
2. Investigate and resolve the crash in module Y for the identified edge case.
3. Review and update data encryption protocols to ensure full compliance with standards.
4. Conduct a follow-up quality assurance analysis after implementing the above actions.

Conclusion:
-----------
The system demonstrates high reliability and compliance with minor areas for improvement. Addressing the identified issues will further enhance the system's quality and performance.
"""

print(qa_report)
# Out:
# Quality Assurance Analysis and Report
# =====================================
#
# Summary:
# ---------
# The quality assurance analysis was conducted to evaluate the performance, reliability, and compliance of the system with the defined standards and requirements.
#
# Findings:
# ---------
# 1. Performance:
#     - The system meets the performance benchmarks in 85% of the test cases.
#     - Identified latency issues in module X during peak load conditions.
#
# 2. Reliability:
#     - The system demonstrated 99.5% uptime over the evaluation period.
#     - A rare edge case caused a crash in module Y.
#
# 3. Compliance:
#     - The system complies with 95% of the defined standards.
#     - Minor deviations were observed in data encryption protocols.
#
# Actions:
# ---------
# 1. Optimize module X to handle peak load conditions more efficiently.
# 2. Investigate and resolve the crash in module Y for the identified edge case.
# 3. Review and update data encryption protocols to ensure full compliance with standards.
# 4. Conduct a follow-up quality assurance analysis after implementing the above actions.
#
# Conclusion:
# -----------
# The system demonstrates high reliability and compliance with minor areas for improvement. Addressing the identified issues will further enhance the system's quality and performance.

# %%
doc = nlp(qa_report)

for token in doc:
    print(f"{token.text:10} {token.pos_:10} {token.dep_:10} {token.head.text:10}")
# Out:
#           SPACE      dep        Analysis
# Quality    PROPN      compound   Analysis
# Assurance  PROPN      compound   Analysis
# Analysis   PROPN      nsubjpass  conducted
# and        CCONJ      cc         Analysis
# Report     PROPN      conj       Analysis
#
#           SPACE      dep        Report
# =          NOUN       punct      Analysis
# =          PRON       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
# =          NOUN       conj       Analysis
#
#
#          SPACE      dep        =
# Summary    NOUN       conj       Analysis
# :          PUNCT      punct      Summary
#
#           SPACE      dep        :
# ---------  PUNCT      punct      Analysis
#
#           SPACE      dep        ---------
# The        DET        det        analysis
# quality    NOUN       compound   assurance
# assurance  NOUN       compound   analysis
# analysis   NOUN       appos      Analysis
# was        AUX        auxpass    conducted
# conducted  VERB       ROOT       conducted
# to         PART       aux        evaluate
# evaluate   VERB       xcomp      conducted
# the        DET        det        performance
# performance NOUN       dobj       evaluate
# ,          PUNCT      punct      performance
# reliability NOUN       conj       performance
# ,          PUNCT      punct      reliability
# and        CCONJ      cc         reliability
# compliance NOUN       conj       reliability
# of         ADP        prep       compliance
# the        DET        det        system
# system     NOUN       pobj       of
# with       ADP        prep       system
# the        DET        det        standards
# defined    VERB       amod       standards
# standards  NOUN       pobj       with
# and        CCONJ      cc         standards
# requirements NOUN       conj       standards
# .          PUNCT      punct      conducted
#
#
#          SPACE      dep        .
# Findings   NOUN       ROOT       Findings
# :          PUNCT      punct      Findings
#
#           SPACE      dep        :
# ---------  NOUN       punct      Findings
#
#           SPACE      dep        ---------
# 1          X          appos      Findings
# .          PUNCT      punct      Findings
# Performance NOUN       ROOT       Performance
# :          PUNCT      punct      Performance
#
#           SPACE      dep        :
# -          PUNCT      punct      Performance
# The        DET        det        system
# system     NOUN       nsubj      meets
# meets      VERB       acl        Performance
# the        DET        det        performance
# performance NOUN       nsubj      benchmarks
# benchmarks VERB       dobj       meets
# in         ADP        prep       benchmarks
# 85         NUM        nummod     %
# %          NOUN       pobj       in
# of         ADP        prep       %
# the        DET        det        cases
# test       NOUN       compound   cases
# cases      NOUN       pobj       of
# .          PUNCT      punct      meets
#
#           SPACE      dep        .
# -          PUNCT      punct      Identified
# Identified VERB       amod       issues
# latency    NOUN       compound   issues
# issues     NOUN       dobj       meets
# in         ADP        prep       issues
# module     NOUN       compound   X
# X          NOUN       pobj       in
# during     ADP        prep       issues
# peak       NOUN       compound   conditions
# load       NOUN       compound   conditions
# conditions NOUN       pobj       during
# .          PUNCT      punct      meets
#
#
#          SPACE      dep        .
# 2          X          nummod     Performance
# .          PUNCT      punct      Performance
# Reliability NOUN       npadvmod   demonstrated
# :          PUNCT      punct      Reliability
#
#           SPACE      dep        :
# -          PUNCT      punct      Reliability
# The        DET        det        system
# system     NOUN       nsubj      demonstrated
# demonstrated VERB       ROOT       demonstrated
# 99.5       NUM        nummod     %
# %          NOUN       compound   uptime
# uptime     NOUN       dobj       demonstrated
# over       ADP        prep       uptime
# the        DET        det        period
# evaluation NOUN       compound   period
# period     NOUN       pobj       over
# .          PUNCT      punct      demonstrated
#
#           SPACE      dep        .
# -          PUNCT      punct      case
# A          DET        det        case
# rare       ADJ        amod       edge
# edge       NOUN       compound   case
# case       NOUN       nsubj      caused
# caused     VERB       ROOT       caused
# a          DET        det        crash
# crash      NOUN       dobj       caused
# in         ADP        prep       crash
# module     NOUN       compound   Y.
# Y.         PROPN      pobj       in
#
#
#          SPACE      dep        Y.
# 3          NUM        nummod     Y.
# .          PUNCT      punct      caused
# Compliance NOUN       dep        complies
# :          PUNCT      punct      Compliance
#
#           SPACE      dep        :
# -          PUNCT      punct      Compliance
# The        DET        det        system
# system     NOUN       nsubj      complies
# complies   VERB       ROOT       complies
# with       ADP        prep       complies
# 95         NUM        nummod     %
# %          NOUN       pobj       with
# of         ADP        prep       %
# the        DET        det        standards
# defined    VERB       amod       standards
# standards  NOUN       pobj       of
# .          PUNCT      punct      complies
#
#           SPACE      dep        .
# -          PUNCT      punct      Minor
# Minor      ADJ        amod       deviations
# deviations NOUN       nsubjpass  observed
# were       AUX        auxpass    observed
# observed   VERB       ROOT       observed
# in         ADP        prep       observed
# data       NOUN       compound   encryption
# encryption NOUN       compound   protocols
# protocols  NOUN       pobj       in
# .          PUNCT      punct      observed
#
#
#          SPACE      dep        .
# Actions    NOUN       ROOT       Actions
# :          PUNCT      punct      Actions
#
#           SPACE      dep        :
# ---------  NOUN       punct      Actions
#
#           SPACE      dep        ---------
# 1          X          appos      Actions
# .          PUNCT      punct      Actions
# Optimize   PROPN      compound   X
# module     NOUN       compound   X
# X          NOUN       nsubj      handle
# to         PART       aux        handle
# handle     VERB       ROOT       handle
# peak       NOUN       compound   conditions
# load       NOUN       compound   conditions
# conditions NOUN       dobj       handle
# more       ADV        advmod     efficiently
# efficiently ADV        advmod     handle
# .          PUNCT      punct      handle
#
#           SPACE      dep        .
# 2          X          ROOT       2
# .          PUNCT      punct      2
# Investigate VERB       ROOT       Investigate
# and        CCONJ      cc         Investigate
# resolve    VERB       conj       Investigate
# the        DET        det        crash
# crash      NOUN       dobj       resolve
# in         ADP        prep       crash
# module     NOUN       compound   Y
# Y          PROPN      pobj       in
# for        ADP        prep       resolve
# the        DET        det        case
# identified VERB       amod       edge
# edge       NOUN       compound   case
# case       NOUN       pobj       for
# .          PUNCT      punct      Investigate
#
#           SPACE      dep        .
# 3          X          meta       Review
# .          PUNCT      punct      3
# Review     VERB       ROOT       Review
# and        CCONJ      cc         Review
# update     VERB       conj       Review
# data       NOUN       compound   encryption
# encryption NOUN       compound   protocols
# protocols  NOUN       dobj       update
# to         PART       aux        ensure
# ensure     VERB       advcl      update
# full       ADJ        amod       compliance
# compliance NOUN       dobj       ensure
# with       ADP        prep       ensure
# standards  NOUN       pobj       with
# .          PUNCT      punct      Review
#
#           SPACE      dep        .
# 4          X          meta       Conduct
# .          PUNCT      punct      4
# Conduct    VERB       ROOT       Conduct
# a          DET        det        analysis
# follow     VERB       amod       assurance
# -          PUNCT      punct      up
# up         ADP        prt        follow
# quality    NOUN       compound   assurance
# assurance  NOUN       compound   analysis
# analysis   NOUN       dobj       Conduct
# after      ADP        prep       Conduct
# implementing VERB       pcomp      after
# the        DET        det        actions
# above      ADJ        amod       actions
# actions    NOUN       dobj       implementing
# .          PUNCT      punct      Conduct
#
#
#          SPACE      dep        .
# Conclusion NOUN       ROOT       Conclusion
# :          PUNCT      punct      Conclusion
#
#           SPACE      dep        :
# ----------- PUNCT      punct      Conclusion
#
#           SPACE      dep        -----------
# The        DET        det        system
# system     NOUN       nsubj      demonstrates
# demonstrates VERB       ROOT       demonstrates
# high       ADJ        amod       reliability
# reliability NOUN       dobj       demonstrates
# and        CCONJ      cc         reliability
# compliance NOUN       conj       reliability
# with       ADP        prep       demonstrates
# minor      ADJ        amod       areas
# areas      NOUN       pobj       with
# for        ADP        prep       demonstrates
# improvement NOUN       pobj       for
# .          PUNCT      punct      demonstrates
# Addressing VERB       csubj      enhance
# the        DET        det        issues
# identified VERB       amod       issues
# issues     NOUN       dobj       Addressing
# will       AUX        aux        enhance
# further    ADV        advmod     enhance
# enhance    VERB       ROOT       enhance
# the        DET        det        system
# system     NOUN       poss       quality
# 's         PART       case       system
# quality    NOUN       dobj       enhance
# and        CCONJ      cc         quality
# performance NOUN       conj       quality
# .          PUNCT      punct      enhance
#
#           SPACE      dep        .

# %%
for ent in doc.sents:
    for token in ent:
        print(token.text, "|", token.pos_, "|", spacy.explain(token.pos_))
# Out:
#  | SPACE | space
# Quality | PROPN | proper noun
# Assurance | PROPN | proper noun
# Analysis | PROPN | proper noun
# and | CCONJ | coordinating conjunction
# Report | PROPN | proper noun
#
#  | SPACE | space
# = | NOUN | noun
# = | PRON | pronoun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
# = | NOUN | noun
#
#
#  | SPACE | space
# Summary | NOUN | noun
# : | PUNCT | punctuation
#
#  | SPACE | space
# --------- | PUNCT | punctuation
#
#  | SPACE | space
# The | DET | determiner
# quality | NOUN | noun
# assurance | NOUN | noun
# analysis | NOUN | noun
# was | AUX | auxiliary
# conducted | VERB | verb
# to | PART | particle
# evaluate | VERB | verb
# the | DET | determiner
# performance | NOUN | noun
# , | PUNCT | punctuation
# reliability | NOUN | noun
# , | PUNCT | punctuation
# and | CCONJ | coordinating conjunction
# compliance | NOUN | noun
# of | ADP | adposition
# the | DET | determiner
# system | NOUN | noun
# with | ADP | adposition
# the | DET | determiner
# defined | VERB | verb
# standards | NOUN | noun
# and | CCONJ | coordinating conjunction
# requirements | NOUN | noun
# . | PUNCT | punctuation
#
#
#  | SPACE | space
# Findings | NOUN | noun
# : | PUNCT | punctuation
#
#  | SPACE | space
# --------- | NOUN | noun
#
#  | SPACE | space
# 1 | X | other
# . | PUNCT | punctuation
# Performance | NOUN | noun
# : | PUNCT | punctuation
#
#      | SPACE | space
# - | PUNCT | punctuation
# The | DET | determiner
# system | NOUN | noun
# meets | VERB | verb
# the | DET | determiner
# performance | NOUN | noun
# benchmarks | VERB | verb
# in | ADP | adposition
# 85 | NUM | numeral
# % | NOUN | noun
# of | ADP | adposition
# the | DET | determiner
# test | NOUN | noun
# cases | NOUN | noun
# . | PUNCT | punctuation
#
#      | SPACE | space
# - | PUNCT | punctuation
# Identified | VERB | verb
# latency | NOUN | noun
# issues | NOUN | noun
# in | ADP | adposition
# module | NOUN | noun
# X | NOUN | noun
# during | ADP | adposition
# peak | NOUN | noun
# load | NOUN | noun
# conditions | NOUN | noun
# . | PUNCT | punctuation
#
#
#  | SPACE | space
# 2 | X | other
# . | PUNCT | punctuation
# Reliability | NOUN | noun
# : | PUNCT | punctuation
#
#      | SPACE | space
# - | PUNCT | punctuation
# The | DET | determiner
# system | NOUN | noun
# demonstrated | VERB | verb
# 99.5 | NUM | numeral
# % | NOUN | noun
# uptime | NOUN | noun
# over | ADP | adposition
# the | DET | determiner
# evaluation | NOUN | noun
# period | NOUN | noun
# . | PUNCT | punctuation
#
#      | SPACE | space
# - | PUNCT | punctuation
# A | DET | determiner
# rare | ADJ | adjective
# edge | NOUN | noun
# case | NOUN | noun
# caused | VERB | verb
# a | DET | determiner
# crash | NOUN | noun
# in | ADP | adposition
# module | NOUN | noun
# Y. | PROPN | proper noun
#
#
#  | SPACE | space
# 3 | NUM | numeral
# . | PUNCT | punctuation
# Compliance | NOUN | noun
# : | PUNCT | punctuation
#
#      | SPACE | space
# - | PUNCT | punctuation
# The | DET | determiner
# system | NOUN | noun
# complies | VERB | verb
# with | ADP | adposition
# 95 | NUM | numeral
# % | NOUN | noun
# of | ADP | adposition
# the | DET | determiner
# defined | VERB | verb
# standards | NOUN | noun
# . | PUNCT | punctuation
#
#      | SPACE | space
# - | PUNCT | punctuation
# Minor | ADJ | adjective
# deviations | NOUN | noun
# were | AUX | auxiliary
# observed | VERB | verb
# in | ADP | adposition
# data | NOUN | noun
# encryption | NOUN | noun
# protocols | NOUN | noun
# . | PUNCT | punctuation
#
#
#  | SPACE | space
# Actions | NOUN | noun
# : | PUNCT | punctuation
#
#  | SPACE | space
# --------- | NOUN | noun
#
#  | SPACE | space
# 1 | X | other
# . | PUNCT | punctuation
# Optimize | PROPN | proper noun
# module | NOUN | noun
# X | NOUN | noun
# to | PART | particle
# handle | VERB | verb
# peak | NOUN | noun
# load | NOUN | noun
# conditions | NOUN | noun
# more | ADV | adverb
# efficiently | ADV | adverb
# . | PUNCT | punctuation
#
#  | SPACE | space
# 2 | X | other
# . | PUNCT | punctuation
# Investigate | VERB | verb
# and | CCONJ | coordinating conjunction
# resolve | VERB | verb
# the | DET | determiner
# crash | NOUN | noun
# in | ADP | adposition
# module | NOUN | noun
# Y | PROPN | proper noun
# for | ADP | adposition
# the | DET | determiner
# identified | VERB | verb
# edge | NOUN | noun
# case | NOUN | noun
# . | PUNCT | punctuation
#
#  | SPACE | space
# 3 | X | other
# . | PUNCT | punctuation
# Review | VERB | verb
# and | CCONJ | coordinating conjunction
# update | VERB | verb
# data | NOUN | noun
# encryption | NOUN | noun
# protocols | NOUN | noun
# to | PART | particle
# ensure | VERB | verb
# full | ADJ | adjective
# compliance | NOUN | noun
# with | ADP | adposition
# standards | NOUN | noun
# . | PUNCT | punctuation
#
#  | SPACE | space
# 4 | X | other
# . | PUNCT | punctuation
# Conduct | VERB | verb
# a | DET | determiner
# follow | VERB | verb
# - | PUNCT | punctuation
# up | ADP | adposition
# quality | NOUN | noun
# assurance | NOUN | noun
# analysis | NOUN | noun
# after | ADP | adposition
# implementing | VERB | verb
# the | DET | determiner
# above | ADJ | adjective
# actions | NOUN | noun
# . | PUNCT | punctuation
#
#
#  | SPACE | space
# Conclusion | NOUN | noun
# : | PUNCT | punctuation
#
#  | SPACE | space
# ----------- | PUNCT | punctuation
#
#  | SPACE | space
# The | DET | determiner
# system | NOUN | noun
# demonstrates | VERB | verb
# high | ADJ | adjective
# reliability | NOUN | noun
# and | CCONJ | coordinating conjunction
# compliance | NOUN | noun
# with | ADP | adposition
# minor | ADJ | adjective
# areas | NOUN | noun
# for | ADP | adposition
# improvement | NOUN | noun
# . | PUNCT | punctuation
# Addressing | VERB | verb
# the | DET | determiner
# identified | VERB | verb
# issues | NOUN | noun
# will | AUX | auxiliary
# further | ADV | adverb
# enhance | VERB | verb
# the | DET | determiner
# system | NOUN | noun
# 's | PART | particle
# quality | NOUN | noun
# and | CCONJ | coordinating conjunction
# performance | NOUN | noun
# . | PUNCT | punctuation
#
#  | SPACE | space

# %%
for ent in doc.sents:
    for token in ent:
        print(token.text, "|", token.pos_, "|", spacy.explain(token.pos_), "|", token.tag_, "|", spacy.explain(token.tag_))
# Out:
#  | SPACE | space | _SP | whitespace
# Quality | PROPN | proper noun | NNP | noun, proper singular
# Assurance | PROPN | proper noun | NNP | noun, proper singular
# Analysis | PROPN | proper noun | NNP | noun, proper singular
# and | CCONJ | coordinating conjunction | CC | conjunction, coordinating
# Report | PROPN | proper noun | NNP | noun, proper singular
#
#  | SPACE | space | _SP | whitespace
# = | NOUN | noun | NNS | noun, plural
# = | PRON | pronoun | PRP | pronoun, personal
# = | NOUN | noun | NNS | noun, plural
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NN | noun, singular or mass
# = | NOUN | noun | NNS | noun, plural
# = | NOUN | noun | NNS | noun, plural
# = | NOUN | noun | NNS | noun, plural
#
#
#  | SPACE | space | _SP | whitespace
# Summary | NOUN | noun | NN | noun, singular or mass
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#  | SPACE | space | _SP | whitespace
# --------- | PUNCT | punctuation | NFP | superfluous punctuation
#
#  | SPACE | space | _SP | whitespace
# The | DET | determiner | DT | determiner
# quality | NOUN | noun | NN | noun, singular or mass
# assurance | NOUN | noun | NN | noun, singular or mass
# analysis | NOUN | noun | NN | noun, singular or mass
# was | AUX | auxiliary | VBD | verb, past tense
# conducted | VERB | verb | VBN | verb, past participle
# to | PART | particle | TO | infinitival "to"
# evaluate | VERB | verb | VB | verb, base form
# the | DET | determiner | DT | determiner
# performance | NOUN | noun | NN | noun, singular or mass
# , | PUNCT | punctuation | , | punctuation mark, comma
# reliability | NOUN | noun | NN | noun, singular or mass
# , | PUNCT | punctuation | , | punctuation mark, comma
# and | CCONJ | coordinating conjunction | CC | conjunction, coordinating
# compliance | NOUN | noun | NN | noun, singular or mass
# of | ADP | adposition | IN | conjunction, subordinating or preposition
# the | DET | determiner | DT | determiner
# system | NOUN | noun | NN | noun, singular or mass
# with | ADP | adposition | IN | conjunction, subordinating or preposition
# the | DET | determiner | DT | determiner
# defined | VERB | verb | VBN | verb, past participle
# standards | NOUN | noun | NNS | noun, plural
# and | CCONJ | coordinating conjunction | CC | conjunction, coordinating
# requirements | NOUN | noun | NNS | noun, plural
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#
#  | SPACE | space | _SP | whitespace
# Findings | NOUN | noun | NNS | noun, plural
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#  | SPACE | space | _SP | whitespace
# --------- | NOUN | noun | NN | noun, singular or mass
#
#  | SPACE | space | _SP | whitespace
# 1 | X | other | LS | list item marker
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# Performance | NOUN | noun | NN | noun, singular or mass
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#      | SPACE | space | _SP | whitespace
# - | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
# The | DET | determiner | DT | determiner
# system | NOUN | noun | NN | noun, singular or mass
# meets | VERB | verb | VBZ | verb, 3rd person singular present
# the | DET | determiner | DT | determiner
# performance | NOUN | noun | NN | noun, singular or mass
# benchmarks | VERB | verb | VBZ | verb, 3rd person singular present
# in | ADP | adposition | IN | conjunction, subordinating or preposition
# 85 | NUM | numeral | CD | cardinal number
# % | NOUN | noun | NN | noun, singular or mass
# of | ADP | adposition | IN | conjunction, subordinating or preposition
# the | DET | determiner | DT | determiner
# test | NOUN | noun | NN | noun, singular or mass
# cases | NOUN | noun | NNS | noun, plural
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#      | SPACE | space | _SP | whitespace
# - | PUNCT | punctuation | HYPH | punctuation mark, hyphen
# Identified | VERB | verb | VBN | verb, past participle
# latency | NOUN | noun | NN | noun, singular or mass
# issues | NOUN | noun | NNS | noun, plural
# in | ADP | adposition | IN | conjunction, subordinating or preposition
# module | NOUN | noun | NN | noun, singular or mass
# X | NOUN | noun | NN | noun, singular or mass
# during | ADP | adposition | IN | conjunction, subordinating or preposition
# peak | NOUN | noun | NN | noun, singular or mass
# load | NOUN | noun | NN | noun, singular or mass
# conditions | NOUN | noun | NNS | noun, plural
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#
#  | SPACE | space | _SP | whitespace
# 2 | X | other | LS | list item marker
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# Reliability | NOUN | noun | NN | noun, singular or mass
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#      | SPACE | space | _SP | whitespace
# - | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
# The | DET | determiner | DT | determiner
# system | NOUN | noun | NN | noun, singular or mass
# demonstrated | VERB | verb | VBD | verb, past tense
# 99.5 | NUM | numeral | CD | cardinal number
# % | NOUN | noun | NN | noun, singular or mass
# uptime | NOUN | noun | NN | noun, singular or mass
# over | ADP | adposition | IN | conjunction, subordinating or preposition
# the | DET | determiner | DT | determiner
# evaluation | NOUN | noun | NN | noun, singular or mass
# period | NOUN | noun | NN | noun, singular or mass
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#      | SPACE | space | _SP | whitespace
# - | PUNCT | punctuation | HYPH | punctuation mark, hyphen
# A | DET | determiner | DT | determiner
# rare | ADJ | adjective | JJ | adjective (English), other noun-modifier (Chinese)
# edge | NOUN | noun | NN | noun, singular or mass
# case | NOUN | noun | NN | noun, singular or mass
# caused | VERB | verb | VBD | verb, past tense
# a | DET | determiner | DT | determiner
# crash | NOUN | noun | NN | noun, singular or mass
# in | ADP | adposition | IN | conjunction, subordinating or preposition
# module | NOUN | noun | NN | noun, singular or mass
# Y. | PROPN | proper noun | NNP | noun, proper singular
#
#
#  | SPACE | space | _SP | whitespace
# 3 | NUM | numeral | CD | cardinal number
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# Compliance | NOUN | noun | NN | noun, singular or mass
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#      | SPACE | space | _SP | whitespace
# - | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
# The | DET | determiner | DT | determiner
# system | NOUN | noun | NN | noun, singular or mass
# complies | VERB | verb | VBZ | verb, 3rd person singular present
# with | ADP | adposition | IN | conjunction, subordinating or preposition
# 95 | NUM | numeral | CD | cardinal number
# % | NOUN | noun | NN | noun, singular or mass
# of | ADP | adposition | IN | conjunction, subordinating or preposition
# the | DET | determiner | DT | determiner
# defined | VERB | verb | VBN | verb, past participle
# standards | NOUN | noun | NNS | noun, plural
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#      | SPACE | space | _SP | whitespace
# - | PUNCT | punctuation | HYPH | punctuation mark, hyphen
# Minor | ADJ | adjective | JJ | adjective (English), other noun-modifier (Chinese)
# deviations | NOUN | noun | NNS | noun, plural
# were | AUX | auxiliary | VBD | verb, past tense
# observed | VERB | verb | VBN | verb, past participle
# in | ADP | adposition | IN | conjunction, subordinating or preposition
# data | NOUN | noun | NN | noun, singular or mass
# encryption | NOUN | noun | NN | noun, singular or mass
# protocols | NOUN | noun | NNS | noun, plural
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#
#  | SPACE | space | _SP | whitespace
# Actions | NOUN | noun | NNS | noun, plural
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#  | SPACE | space | _SP | whitespace
# --------- | NOUN | noun | NN | noun, singular or mass
#
#  | SPACE | space | _SP | whitespace
# 1 | X | other | LS | list item marker
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# Optimize | PROPN | proper noun | NNP | noun, proper singular
# module | NOUN | noun | NN | noun, singular or mass
# X | NOUN | noun | NN | noun, singular or mass
# to | PART | particle | TO | infinitival "to"
# handle | VERB | verb | VB | verb, base form
# peak | NOUN | noun | NN | noun, singular or mass
# load | NOUN | noun | NN | noun, singular or mass
# conditions | NOUN | noun | NNS | noun, plural
# more | ADV | adverb | RBR | adverb, comparative
# efficiently | ADV | adverb | RB | adverb
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#  | SPACE | space | _SP | whitespace
# 2 | X | other | LS | list item marker
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# Investigate | VERB | verb | VB | verb, base form
# and | CCONJ | coordinating conjunction | CC | conjunction, coordinating
# resolve | VERB | verb | VB | verb, base form
# the | DET | determiner | DT | determiner
# crash | NOUN | noun | NN | noun, singular or mass
# in | ADP | adposition | IN | conjunction, subordinating or preposition
# module | NOUN | noun | NN | noun, singular or mass
# Y | PROPN | proper noun | NNP | noun, proper singular
# for | ADP | adposition | IN | conjunction, subordinating or preposition
# the | DET | determiner | DT | determiner
# identified | VERB | verb | VBN | verb, past participle
# edge | NOUN | noun | NN | noun, singular or mass
# case | NOUN | noun | NN | noun, singular or mass
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#  | SPACE | space | _SP | whitespace
# 3 | X | other | LS | list item marker
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# Review | VERB | verb | VB | verb, base form
# and | CCONJ | coordinating conjunction | CC | conjunction, coordinating
# update | VERB | verb | VB | verb, base form
# data | NOUN | noun | NN | noun, singular or mass
# encryption | NOUN | noun | NN | noun, singular or mass
# protocols | NOUN | noun | NNS | noun, plural
# to | PART | particle | TO | infinitival "to"
# ensure | VERB | verb | VB | verb, base form
# full | ADJ | adjective | JJ | adjective (English), other noun-modifier (Chinese)
# compliance | NOUN | noun | NN | noun, singular or mass
# with | ADP | adposition | IN | conjunction, subordinating or preposition
# standards | NOUN | noun | NNS | noun, plural
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#  | SPACE | space | _SP | whitespace
# 4 | X | other | LS | list item marker
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# Conduct | VERB | verb | VB | verb, base form
# a | DET | determiner | DT | determiner
# follow | VERB | verb | VB | verb, base form
# - | PUNCT | punctuation | HYPH | punctuation mark, hyphen
# up | ADP | adposition | RP | adverb, particle
# quality | NOUN | noun | NN | noun, singular or mass
# assurance | NOUN | noun | NN | noun, singular or mass
# analysis | NOUN | noun | NN | noun, singular or mass
# after | ADP | adposition | IN | conjunction, subordinating or preposition
# implementing | VERB | verb | VBG | verb, gerund or present participle
# the | DET | determiner | DT | determiner
# above | ADJ | adjective | JJ | adjective (English), other noun-modifier (Chinese)
# actions | NOUN | noun | NNS | noun, plural
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#
#  | SPACE | space | _SP | whitespace
# Conclusion | NOUN | noun | NN | noun, singular or mass
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#  | SPACE | space | _SP | whitespace
# ----------- | PUNCT | punctuation | NFP | superfluous punctuation
#
#  | SPACE | space | _SP | whitespace
# The | DET | determiner | DT | determiner
# system | NOUN | noun | NN | noun, singular or mass
# demonstrates | VERB | verb | VBZ | verb, 3rd person singular present
# high | ADJ | adjective | JJ | adjective (English), other noun-modifier (Chinese)
# reliability | NOUN | noun | NN | noun, singular or mass
# and | CCONJ | coordinating conjunction | CC | conjunction, coordinating
# compliance | NOUN | noun | NN | noun, singular or mass
# with | ADP | adposition | IN | conjunction, subordinating or preposition
# minor | ADJ | adjective | JJ | adjective (English), other noun-modifier (Chinese)
# areas | NOUN | noun | NNS | noun, plural
# for | ADP | adposition | IN | conjunction, subordinating or preposition
# improvement | NOUN | noun | NN | noun, singular or mass
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# Addressing | VERB | verb | VBG | verb, gerund or present participle
# the | DET | determiner | DT | determiner
# identified | VERB | verb | VBN | verb, past participle
# issues | NOUN | noun | NNS | noun, plural
# will | AUX | auxiliary | MD | verb, modal auxiliary
# further | ADV | adverb | RB | adverb
# enhance | VERB | verb | VB | verb, base form
# the | DET | determiner | DT | determiner
# system | NOUN | noun | NN | noun, singular or mass
# 's | PART | particle | POS | possessive ending
# quality | NOUN | noun | NN | noun, singular or mass
# and | CCONJ | coordinating conjunction | CC | conjunction, coordinating
# performance | NOUN | noun | NN | noun, singular or mass
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#  | SPACE | space | _SP | whitespace

# %%
for ent in doc.sents:
    for token in ent:
        if token.pos_ in ['X', 'SYM', 'PUNCT', 'SPACE']:
            print(token.text, "|", token.pos_, "|", spacy.explain(token.pos_), "|", token.tag_, "|", spacy.explain(token.tag_))
# Out:
#  | SPACE | space | _SP | whitespace
#
#  | SPACE | space | _SP | whitespace
#
#
#  | SPACE | space | _SP | whitespace
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#  | SPACE | space | _SP | whitespace
# --------- | PUNCT | punctuation | NFP | superfluous punctuation
#
#  | SPACE | space | _SP | whitespace
# , | PUNCT | punctuation | , | punctuation mark, comma
# , | PUNCT | punctuation | , | punctuation mark, comma
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#
#  | SPACE | space | _SP | whitespace
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#  | SPACE | space | _SP | whitespace
#
#  | SPACE | space | _SP | whitespace
# 1 | X | other | LS | list item marker
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#      | SPACE | space | _SP | whitespace
# - | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#      | SPACE | space | _SP | whitespace
# - | PUNCT | punctuation | HYPH | punctuation mark, hyphen
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#
#  | SPACE | space | _SP | whitespace
# 2 | X | other | LS | list item marker
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#      | SPACE | space | _SP | whitespace
# - | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#      | SPACE | space | _SP | whitespace
# - | PUNCT | punctuation | HYPH | punctuation mark, hyphen
#
#
#  | SPACE | space | _SP | whitespace
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#      | SPACE | space | _SP | whitespace
# - | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#      | SPACE | space | _SP | whitespace
# - | PUNCT | punctuation | HYPH | punctuation mark, hyphen
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#
#  | SPACE | space | _SP | whitespace
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#  | SPACE | space | _SP | whitespace
#
#  | SPACE | space | _SP | whitespace
# 1 | X | other | LS | list item marker
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#  | SPACE | space | _SP | whitespace
# 2 | X | other | LS | list item marker
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#  | SPACE | space | _SP | whitespace
# 3 | X | other | LS | list item marker
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#  | SPACE | space | _SP | whitespace
# 4 | X | other | LS | list item marker
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# - | PUNCT | punctuation | HYPH | punctuation mark, hyphen
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#
#  | SPACE | space | _SP | whitespace
# : | PUNCT | punctuation | : | punctuation mark, colon or ellipsis
#
#  | SPACE | space | _SP | whitespace
# ----------- | PUNCT | punctuation | NFP | superfluous punctuation
#
#  | SPACE | space | _SP | whitespace
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
#
#  | SPACE | space | _SP | whitespace

# %%
filtered_tokens = [token for token in doc if token.pos_ in ['X', 'SYM', 'PUNCT', 'SPACE']]
print(filtered_tokens)
# Out:
# [
# ,
# ,
#
# , :,
# , ---------,
# , ,, ,, .,
#
# , :,
# ,
# , 1, ., :,
#     , -, .,
#     , -, .,
#
# , 2, ., :,
#     , -, .,
#     , -,
#
# , ., :,
#     , -, .,
#     , -, .,
#
# , :,
# ,
# , 1, ., .,
# , 2, ., .,
# , 3, ., .,
# , 4, ., -, .,
#
# , :,
# , -----------,
# , ., .,
# ]

# %%
# counts of different POS tags
counts = doc.count_by(spacy.attrs.POS)
for k, v in sorted(counts.items()):
    print(f"{k}: {doc.vocab[k].text:{10}} {v}")
# Out:
# 84: ADJ        6
# 85: ADP        18
# 86: ADV        3
# 87: AUX        3
# 89: CCONJ      7
# 90: DET        20
# 92: NOUN       109
# 93: NUM        4
# 94: PART       4
# 95: PRON       1
# 96: PROPN      7
# 97: PUNCT      37
# 100: VERB       25
# 101: X          6
# 103: SPACE      26
